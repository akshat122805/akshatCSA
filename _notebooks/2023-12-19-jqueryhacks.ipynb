// %% [markdown]
// ---
// layout: post
// title: JQuery Hacks
// toc: true
// comments: true
// description:
// courses: { csa: {week: 15} }
// type: tangibles
// ---

// %% [markdown]
// Question: What are some real life applications of jQuery? Name at least two you can think of
// - Form Validation: Validate user input on the client side before submitting the form to the server
// - Slideshows, galleries, etc.: Create image galleries and sliders on websites with animation capabilities make it easy to implement features like image slideshows and lightboxes
//
// popcorn hack: talk about usage of one of four elements of CRUD from your project in tri 1. Focus on how CRUD was implemented.
// - My project last trimester was a JFreechart implementation where users can input a number and it creates a dataset in the backend, this employed the 'R' functionality of CRUD as the server has to read the user input in order to create a real-time graph.

// %% [markdown]
// # Free Response and MCQ

// %% [markdown]
// 1. What does CRUD stand for?
//     - Create
//     - Read
//     - Update
//     - Delete
//
// 2. What are the HTTP verbs that are associated with each CRUD action?
//     - C - POST
//     - R - GET
//     - U - UPDATE
//     - D - DELETE
//
// 3. What is JQuery?
//     - a library that allows us to use some of JavaScript’s built in functions
//
// 4. Match A, B, and C into the JQuery event handler for a data table
//     - A: 'click'
//     - B: '.delete-btn'
//     - C: '#data-table'
//
//     $(???).on(???, ???, function() {
//     // code
//   });
//
//   $('.delete-btn').on(click, #data-table, function() {
//     //code
//   });
//
// 5. Why do we use JQUERY with CRUD?
// - JQuery is frontend, while CRUD is done on backend. Using the combination of the two allows for efficient and simpler backend and frontend code connections.

// %% [markdown]
// # Finish the update JQUERY function
// - its all the way at the end, you should see the green comment
// - you can choose to use the two lines I've already given or not

// %% [markdown]
// <script src="https://code.jquery.com/jquery-3.6.4.min.js"></script>
//
// <style>
//   body {
//     background-color: #b3e0f2; /* Ocean Blue */
//     font-family: 'Verdana', sans-serif;
//     margin: 0;
//     padding: 0;
//   }
//
//   table {
//     border-collapse: collapse;
//     width: 100%;
//     margin-top: 20px;
//   }
//
//   th, td {
//     border: 1px solid #6caedd; /* Ocean Blue */
//     padding: 10px;
//     text-align: left;
//   }
//
//   th {
//     background-color: #3b8eb5; /* Deep Ocean Blue */
//     color: white;
//   }
//
//   button {
//     background-color: #3b8eb5; /* Deep Ocean Blue */
//     color: white;
//     border: none;
//     padding: 8px 12px;
//     cursor: pointer;
//   }
//
//   button:hover {
//     background-color: #6caedd; /* Lighter Ocean Blue */
//   }
// </style>
//
// <table id="ocean-table">
//   <thead>
//     <tr>
//       <th>ID</th>
//       <th>Name</th>
//       <th>Email</th>
//       <th>Actions</th>
//     </tr>
//   </thead>
//   <tbody>
//     <!-- Data will be dynamically added here -->
//   </tbody>
// </table>
//
// <button id="add-character-btn">Add Ocean Character</button>
//
// <script>
//   const oceanData = [
//     { id: 1, name: 'Coral', email: 'coral@example.com' },
//     { id: 2, name: 'Marlin', email: 'marlin@example.com' }
//   ];
//
//   function renderOceanData(data) {
//     const tableBody = $('#ocean-table tbody');
//     tableBody.empty();
//
//     data.forEach(item => {
//       const row = `
//         <tr>
//           <td>${item.id}</td>
//           <td>${item.name}</td>
//           <td>${item.email}</td>
//           <td>
//             <button class="edit-btn" data-id="${item.id}">Edit</button>
//             <button class="remove-btn" data-id="${item.id}">Remove</button>
//           </td>
//         </tr>
//       `;
//       tableBody.append(row);
//     });
//   }
//
//   function addOceanCharacter() {
//     const newName = prompt('Enter the name of the Ocean character:');
//     const newEmail = prompt('Enter the email of the Ocean character:');
//     const newId = oceanData.length + 1;
//
//     const newData = [...oceanData, { id: newId, name: newName, email: newEmail }];
//     renderOceanData(newData);
//   }
//
//   $('#add-character-btn').on('click', addOceanCharacter);
//
//   $('#ocean-table').on('click', '.remove-btn', function() {
//     const idToRemove = $(this).data('id');
//     const newData = oceanData.filter(item => item.id !== idToRemove);
//     renderOceanData(newData);
//   });
//
//   $('#ocean-table').on('click', '.edit-btn', function() {
//     const idToEdit = $(this).data('id');
//     const editIndex = oceanData.findIndex(item => item.id === idToEdit);
//     const newName = prompt('Enter a new name:');
//     const newEmail = prompt('Enter a new email:');
//     oceanData[editIndex] = { id: idToEdit, name: newName, email: newEmail };
//     renderOceanData(oceanData);
//   });
//
//   // Initial rendering
//   renderOceanData(oceanData);
// </script>
